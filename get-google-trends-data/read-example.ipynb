# %%
import pandas as pd
import datetime

# %%
input_file = "pytrends/data/google-trends-search-topics-US-NY.csv"
date = datetime.date(2019, 6, 17)

# %%
df = pd.read_csv(input_file)
google_trends_topic = df.loc[df['Date'] == str(date)]

# %%
google_trends_topic
# Out:
#           Date                                      Search topics   Rising
# 40  2019-06-17                Gloria Vanderbilt - American artist  +4,350%
# 41  2019-06-17                           Google Classroom - Topic    +450%
# 42  2019-06-17               FedEx - Air courier services company    +400%
# 43  2019-06-17                       Mathematics - Field of study    +250%
# 44  2019-06-17                        Natural environment - Topic    +200%
# 45  2019-06-17          Google Docs, Sheets, and Slides - Website    +170%
# 46  2019-06-17                                      Court - Topic    +160%
# 47  2019-06-17                                 LinkedIn - Website    +150%
# 48  2019-06-17         Microsoft Corporation - Technology company    +150%
# 49  2019-06-17                                      Gmail - Topic    +120%
# 50  2019-06-17                       Regents Examinations - Topic    +120%
# ...

# %%
input_queries_file = "pytrends/data/google-trends-search-queries-US-NY.csv"

# %%
df_queries = pd.read_csv(input_queries_file)
google_trends_queries = df_queries.loc[df_queries['Date'] == str(date)]

# %%
google_trends_queries
# Out:
#            Date       Search queries    Rising
# 940  2019-06-17    gloria vanderbilt  Breakout
# 941  2019-06-17               iready   +1,150%
# 942  2019-06-17               kahoot   +1,150%
# 943  2019-06-17       fedex tracking   +1,050%
# 944  2019-06-17      cool math games   +1,000%
# 945  2019-06-17                abcya     +900%
# 946  2019-06-17      anderson cooper     +800%
# 947  2019-06-17            dow jones     +750%
# 948  2019-06-17  post office near me     +650%
# 949  2019-06-17        patrick drahi     +450%
# 950  2019-06-17  nyc parking tickets     +450%
# 951  2019-06-17        nyc doe email     +450%
# 952  2019-06-17        yahoo finance     +450%
# 953  2019-06-17                sesis     +400%
# 954  2019-06-17                run 3     +350%
# 955  2019-06-17        google slides     +350%
# 956  2019-06-17            pupilpath     +350%
# 957  2019-06-17                fedex     +350%
# 958  2019-06-17    adp workforce now     +350%
# ...
